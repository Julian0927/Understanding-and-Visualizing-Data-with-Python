# %% [markdown]
# # ***Unit Testing***
#
#
# While we will not cover the [unit testing library](https://docs.python.org/3/library/unittest.html) that python has, we wanted to introduce you to a simple way that you can test your code. `Unit testing` is important because it is the only way you can be sure that your code is do what you think it is doing.
# Remember, just because there are no errors does not mean your code is correct.

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
# Show all columns when looking at dataframe
pd.set_option('display.max_columns', 100)

# %%
# Download NHANES 2015-2016 data
df = pd.read_csv("nhanes_2015_2016.csv")
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0       1.0       5.0       1.0         2  134671.37        1       125
# 1       2.0       3.0       3.0         1   24328.56        1       125
# 2       1.0       3.0       1.0         2   12400.01        1       131
# 3       1.0       5.0       6.0         1  102718.00        1       131
# 4       1.0       4.0       3.0         5   17627.67        2       126
#
#    INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
# we change the indices of the dataframe
df.index = range(1,df.shape[0]+1)
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 1  83732     1.0     NaN     1.0       1         1        62         3
# 2  83733     1.0     NaN     6.0       1         1        53         3
# 3  83734     1.0     NaN     NaN       1         1        78         3
# 4  83735     2.0     1.0     1.0       2         2        56         3
# 5  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 1       1.0       5.0       1.0         2  134671.37        1       125
# 2       2.0       3.0       3.0         1   24328.56        1       125
# 3       1.0       3.0       1.0         2   12400.01        1       131
# 4       1.0       5.0       6.0         1  102718.00        1       131
# 5       1.0       4.0       3.0         5   17627.67        2       126
#
#    INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %% [markdown]
# # ***Goal***
# We want to find the mean of first 100 rows of 'BPXSY1' when 'RIDAGEYR' > 60

# %%
df[df["RIDAGEYR"] > 60].head()
# Out:
#      SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 1   83732     1.0     NaN     1.0       1         1        62         3
# 3   83734     1.0     NaN     NaN       1         1        78         3
# 6   83737     2.0     2.0     NaN       2         2        72         1
# 14  83754     2.0     1.0     1.0       2         2        67         2
# 15  83755     1.0     NaN     3.0       2         1        67         4
#
#     DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 1        1.0       5.0       1.0         2  134671.37        1       125
# 3        1.0       3.0       1.0         2   12400.01        1       131
# 6        2.0       2.0       4.0         5   11252.31        1       128
# 14       1.0       5.0       1.0         7   10495.87        1       128
# 15       1.0       5.0       2.0         1   14080.10        1       126
#
#     INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
x=list(df[df["RIDAGEYR"] > 60].index)
y=x[0:99]
z=df[df["RIDAGEYR"] > 60].loc[y]
resultado=pd.Series.mean(z["BPXSY1"])
resultado
# Out:
# 136.61052631578949

# %%
columna=list(df[df["RIDAGEYR"] > 60].columns).index("BPXSY1")
pd.Series.mean(df[df["RIDAGEYR"] > 60].iloc[0:99, columna])
# Out:
# 136.61052631578949

# %%
np.mean(df[df["RIDAGEYR"] > 60].iloc[0:99, columna])
# Out:
# 136.61052631578949

# %%
np.repeat([3,1],5)
# Out:
# array([3, 3, 3, 3, 3, 1, 1, 1, 1, 1])

# %%
# test our code on only ten rows so we can easily check
test = pd.DataFrame({'col1': np.repeat([3,1],5), 'col2': range(3,13)}, index=range(1,11))
test
# Out:
#     col1  col2
# 1      3     3
# 2      3     4
# 3      3     5
# 4      3     6
# 5      3     7
# 6      1     8
# 7      1     9
# 8      1    10
# 9      1    11
# 10     1    12

# %%
# should return 5

indices_renglones=test[test["col1"] > 2].index
print(indices_renglones)
print(pd.Series.mean(test[test["col1"] > 2].loc[indices_renglones, "col2"]))
# Out:
# Int64Index([1, 2, 3, 4, 5], dtype='int64')
# 5.0

# %% [markdown]
# What went wrong?

# %%
# 0 is not in the row index labels because the second row's value is < 2. For now, pandas defaults to filling this
# with NaN
test[test["col1"] > 2].loc[range(0,5), 'col2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-e85f17447b2e> in <module>
# ----> 1 test[test.col1 > 2].loc[range(0,5), 'col2']
#       2 # 0 is not in the row index labels because the second row's value is < 2. For now, pandas defaults to filling this
#       3 # with NaN
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1098     def _getitem_tuple(self, tup: tuple):
#    1099         with suppress(IndexingError):
# ...

# %%
# Using the .iloc method instead, we are correctly choosing the first 5 rows, regardless of their row labels
test[test["col1"] >2].iloc[range(0,5), 1]
# Out:
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# Name: col2, dtype: int64

# %%
pd.Series.mean(test[test.col1 >2].iloc[range(0,5), 1])
# Out:
# 5.0

# %%
# We can compare what our real dataframe looks like with the incorrect and correct methods
# Filled with NaN whenever a row label does not meet the condition
df[df.RIDAGEYR > 60].loc[range(0,5), :]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-539ad5043fdf> in <module>
#       1 # We can compare what our real dataframe looks like with the incorrect and correct methods
# ----> 2 df[df.RIDAGEYR > 60].loc[range(0,5), :] # Filled with NaN whenever a row label does not meet the condition
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# ...

# %%
# Correct picks the first fice rows such that 'RIDAGEYR" > 60
df[df["RIDAGEYR"] > 60].iloc[range(0,5), :]
# Out:
#      SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0   83732     1.0     NaN     1.0       1         1        62         3
# 2   83734     1.0     NaN     NaN       1         1        78         3
# 5   83737     2.0     2.0     NaN       2         2        72         1
# 13  83754     2.0     1.0     1.0       2         2        67         2
# 14  83755     1.0     NaN     3.0       2         1        67         4
#
#     DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0        1.0       5.0       1.0         2  134671.37        1       125
# 2        1.0       3.0       1.0         2   12400.01        1       131
# 5        2.0       2.0       4.0         5   11252.31        1       128
# 13       1.0       5.0       1.0         7   10495.87        1       128
# 14       1.0       5.0       2.0         1   14080.10        1       126
#
#     INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
# Applying the correct method to the original question about BPXSY1
print(pd.Series.mean(df[df.RIDAGEYR > 60].iloc[range(0,99), 16]))

# Another way to reference the BPXSY1 variable
print(pd.Series.mean(df[df.RIDAGEYR > 60].iloc[range(0,99), df.columns.get_loc('BPXSY1')]))
# Out:
# 136.61052631578949
# 136.61052631578949
