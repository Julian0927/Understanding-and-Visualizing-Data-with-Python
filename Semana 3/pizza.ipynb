# %% [markdown]
# ### ***Business Memorandum***
# ### ***Date: October, 31 , 2022***
# ### ***TPZZ Pizza Company***
# ### ***From: Kurt Gödel, Consulting Specialist***
# ### ***Subject: Collection Of Important Data For The Growth Of The Company***
#
#
# $ \ $
#
# Next I will show you a statistical model which will show some characteristics to highlight of our delicious pizza with respect to that of the competition. More particularly we will compare our pizza with the biggest pizza company called pizza hut. Therefore,  these results, we will get very satisfactory results regarding sales in the near future, because we know that Tpzz is marvelous.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This model consists of 4 categories shown below:

# %% [markdown]
# * ***Category 1 (data collection).***
#
# In the main shopping centers, we will give free samples of our best pizza (the dragonite Tpzz). The people who receive our delicious pizza will do a survey, which will show the particular preferences of our pizza with respect to those of the pizza hut company.

# %% [markdown]
# * ***Category 2 (survey results study).*** **texto en negrita**
#
# In this part, we will study the survey results. It is important to note that every survey has the following form:

# %%
import pandas as pd
df=pd.DataFrame({" Freshness ":["",""]," Customer Service ":["",""]," Taste ":["",""]," Price ":["",""]})
df.rename(index={0:"TPZZ",1:"HUT"},inplace=True)
df
# Out:
#       Freshness   Customer Service   Taste   Price
# TPZZ
# HUT

# %% [markdown]
# and people will grade each box with an integer between 0 and 5, taking into account that the minimum satisfaction is 0 and the maximum is 5.

# %% [markdown]
# * ***Category 3 (discard scattered or incomplete data).***
#
# In this part we discard the scattered or incomplete data, to obtain an "acceptable" data set with which we can identify possible statistical distributions that describe our data in a probabilistic way.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * ***Category 4 (show results).***
#
# In this last step we make marketing announcements showing our results in favor of the other company. This with the aim of showing people that our delicious pizza stands out among all pizzas, since it revalidates in some factors with the best pizzeria.
